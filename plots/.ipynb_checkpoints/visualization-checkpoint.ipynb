# %%
import networkx as nx
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../data/200kdataset.csv')

# %%
df.boxplot(column='u_n_cat', by='y')
# Out:
# <Axes: title={'center': 'u_n_cat'}, xlabel='y'>

# %%
df.boxplot(column='v_n_cat', by='y')
# Out:
# <Axes: title={'center': 'v_n_cat'}, xlabel='y'>

# %%
df.boxplot(column='aa_score', by='y')
# Out:
# <Axes: title={'center': 'aa_score'}, xlabel='y'>

# %%
df.boxplot(column='u_deg', by='y')
# Out:
# <Axes: title={'center': 'u_deg'}, xlabel='y'>

# %%
df.boxplot(column='v_deg', by='y')
# Out:
# <Axes: title={'center': 'v_deg'}, xlabel='y'>

# %%
df.boxplot(column='u_bet', by='y')
# Out:
# <Axes: title={'center': 'u_bet'}, xlabel='y'>

# %%
df.boxplot(column='v_bet', by='y')
# Out:
# <Axes: title={'center': 'v_bet'}, xlabel='y'>

# %%
df.boxplot(column='u_clo', by='y')
# Out:
# <Axes: title={'center': 'u_clo'}, xlabel='y'>

# %%
df.boxplot(column='v_clo', by='y')
# Out:
# <Axes: title={'center': 'v_clo'}, xlabel='y'>

# %%
df.boxplot(column='u_eig', by='y')
# Out:
# <Axes: title={'center': 'u_eig'}, xlabel='y'>

# %%
df.boxplot(column='v_eig', by='y')
# Out:
# <Axes: title={'center': 'v_eig'}, xlabel='y'>

# %%
df.boxplot(column='u_stars', by='y')
# Out:
# <Axes: title={'center': 'u_stars'}, xlabel='y'>

# %%
df.boxplot(column='v_stars', by='y')
# Out:
# <Axes: title={'center': 'v_stars'}, xlabel='y'>

# %%
df.boxplot(column='u_rev_count', by='y')
# Out:
# <Axes: title={'center': 'u_rev_count'}, xlabel='y'>

# %%
df.boxplot(column='v_rev_count', by='y')
# Out:
# <Axes: title={'center': 'v_rev_count'}, xlabel='y'>

# %%
axis_corr = sns.heatmap(
df.drop(columns=['y']).corr(),
vmin=-1, vmax=1, center=0,
cmap=sns.diverging_palette(50, 500, n=500),
square=True
)

plt.show()
